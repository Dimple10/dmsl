# %%
from importlib import reload 
import mass_function as mf
import mass_profile as mp
import numpy as np
import matplotlib.pyplot as plt
#from scipy.integrate import quad
import astropy.units as u
import scipy
import pandas as pd
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# /Users/fangirl/miniconda3/envs/project/lib/python3.8/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
# %%time
press_s= mf.PressSchechter(m_l = np.logspace(0,8,100))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File <timed exec>:1
#
# File <string>:15, in __init__(self, n_l, m_l, sur, Name, den_n_l, sig, der, R, del_crit, nparams, param_names, param_range)
#
# File ~/Repos/Kris/dmsl/dmsl/mass_function.py:618, in PressSchechter.__post_init__(self)
#     616 self.radius()
#     617 self.calc_sig()
# --> 618 self.der_sig()
#     619 self.find_Nl()
#
# File ~/Repos/Kris/dmsl/dmsl/mass_function.py:586, in PressSchechter.der_sig(self)
#     584 def der_sig(self): #Gives 2sig *dsig/dR
#     585     integrand_der = lambda k: self.func_der(k) * k**2 * self.getPk(k)
# --> 586     f_1 = quad_vec(integrand_der, 1e-3, 100000, limit=100)
#     587     self.der = f_1[0]
#     588     return self.der
#
# File ~/miniconda3/envs/project/lib/python3.8/site-packages/scipy/integrate/_quad_vec.py:369, in quad_vec(f, a, b, epsabs, epsrel, norm, cache_size, limit, workers, points, quadrature, full_output)
#     366     err_sum += -neg_old_err
#     368 # Subdivide intervals
# --> 369 for dint, derr, dround_err, subint, dneval in mapwrapper(_subdivide_interval, to_process):
#     370     neval += dneval
#     371     global_integral += dint
#
# File ~/miniconda3/envs/project/lib/python3.8/site-packages/scipy/integrate/_quad_vec.py:426, in _subdivide_interval(args)
#     423 if getattr(_quadrature, 'cache_size', 0) > 0:
#     424     f = functools.lru_cache(_quadrature.cache_size)(f)
# --> 426 s1, err1, round1 = _quadrature(a, c, f, norm_func)
#     427 dneval = _quadrature.num_eval
#     428 s2, err2, round2 = _quadrature(c, b, f, norm_func)
#
# File ~/miniconda3/envs/project/lib/python3.8/site-packages/scipy/integrate/_quad_vec.py:582, in _quadrature_gk21(a, b, f, norm_func)
#     559 # 21-point weights
#     560 v = (0.011694638867371874278064396062192,
#     561      0.032558162307964727478818972459390,
#     562      0.054755896574351996031381300244580,
#    (...)
#     579      0.032558162307964727478818972459390,
#     580      0.011694638867371874278064396062192)
# --> 582 return _quadrature_gk(a, b, f, norm_func, x, w, v)
#
# File ~/miniconda3/envs/project/lib/python3.8/site-packages/scipy/integrate/_quad_vec.py:483, in _quadrature_gk(a, b, f, norm_func, x, w, v)
#     481 s_k_abs = 0.0
#     482 for i in range(len(x)):
# --> 483     ff = f(c + h*x[i])
#     484     fv[i] = ff
#     486     vv = v[i]
#
# File ~/Repos/Kris/dmsl/dmsl/mass_function.py:585, in PressSchechter.der_sig.<locals>.<lambda>(k)
#     584 def der_sig(self): #Gives 2sig *dsig/dR
# --> 585     integrand_der = lambda k: self.func_der(k) * k**2 * self.getPk(k)
#     586     f_1 = quad_vec(integrand_der, 1e-3, 100000, limit=100)
#     587     self.der = f_1[0]
#
# File ~/Repos/Kris/dmsl/dmsl/mass_function.py:580, in PressSchechter.func_der(self, k)
#     578 f_4 = (-3 / self.R.value) * 1/u.Mpc *(u.Mpc / u.pc).to('') * np.sin((k * (1 / u.Mpc) * self.R).to('') * u.rad)
#     579 f_5 = 3 * (k * (1 / u.Mpc)) * np.cos((k * (1 / u.Mpc) * self.R).to('') * u.rad)
# --> 580 f_6 = 1/u.Mpc * (k ** 2 * (1 / u.Mpc) * self.R).to('') * np.sin((k * (1 / u.Mpc) * self.R).to('') * u.rad)
#     581 f = ((f_2 * np.abs(f_3)) * f_1 * f_2 * (f_4 + f_5 + f_6)).to('')
#     582 return f
#
# File ~/miniconda3/envs/project/lib/python3.8/site-packages/astropy/units/quantity.py:855, in Quantity.to(self, unit, equivalencies, copy)
#     851 unit = Unit(unit)
#     852 if copy:
#     853     # Avoid using to_value to ensure that we make a copy. We also
#     854     # don't want to slow down this method (esp. the scalar case).
# --> 855     value = self._to_value(unit, equivalencies)
#     856 else:
#     857     # to_value only copies if necessary
#     858     value = self.to_value(unit, equivalencies)
#
# File ~/miniconda3/envs/project/lib/python3.8/site-packages/astropy/units/quantity.py:809, in Quantity._to_value(self, unit, equivalencies)
#     806     equivalencies = self._equivalencies
#     807 if not self.dtype.names or isinstance(self.unit, StructuredUnit):
#     808     # Standard path, let unit to do work.
# --> 809     return self.unit.to(unit, self.view(np.ndarray),
#     810                         equivalencies=equivalencies)
#     812 else:
#     813     # The .to() method of a simple unit cannot convert a structured
#     814     # dtype, so we work around it, by recursing.
#     815     # TODO: deprecate this?
#     816     # Convert simple to Structured on initialization?
#     817     result = np.empty_like(self.view(np.ndarray))
#
# File ~/miniconda3/envs/project/lib/python3.8/site-packages/astropy/units/core.py:1130, in UnitBase.to(self, other, value, equivalencies)
#    1128     return UNITY
#    1129 else:
# -> 1130     return self._get_converter(Unit(other),
#    1131                                equivalencies=equivalencies)(value)
#
# File ~/miniconda3/envs/project/lib/python3.8/site-packages/astropy/units/core.py:1042, in UnitBase._get_converter.<locals>.<lambda>(val)
#    1040         return unit_scale_converter
#    1041     else:
# -> 1042         return lambda val: scale * _condition_arg(val)
#    1044 # if that doesn't work, maybe we can do it with equivalencies?
#    1045 try:
#
# KeyboardInterrupt:

# %%
# %%time
reload(mf)
press_test= mf.PressSchechter_test(m_l = np.logspace(0,8,100))
# Out:
# CPU times: user 144 ms, sys: 1.65 ms, total: 146 ms
# Wall time: 146 ms

# %% [markdown]
# ## Integration tests

# %%
k = np.logspace(-3,5,100)
plt.title('Press-Schechter Sigma')
plt.xlabel(r'Subhalo Mass [$M_{\odot}]$')
plt.xscale('log')
plt.yscale('log')
plt.ylabel(r'$\sigma$')
#plt.plot(k,press_s.sig, label='quad')
plt.plot(k,press_test.sig, label='trapz')
plt.legend()
plt.show()

# %%
k = np.logspace(-3,5, 100)
plt.title('Press-Schechter Sigma Der')
plt.xlabel(r'k')
plt.xscale('log')
#plt.yscale('log')
plt.ylabel(r'$\sigma der$')
# plt.plot(k[2:],press_s.der[2:], label='quad')
plt.plot(k,press_test.der, label='trapz')
plt.legend()
plt.show()

# %%
plt.title('Press-Schechter Function')
plt.xlabel(r'Subhalo Mass [$M_{\odot}]$')
plt.xscale('log')
plt.yscale('log')
plt.ylabel(r'dN/dlnM $\,\,\,\, [\mathrm{Mpc}]^-3$')
#plt.plot(press_s.m_l[2:],press_s.m_l[2:]*press_s.den_n_l[2:], label='quad')
plt.plot(press_test.m_l,press_test.m_l*press_test.den_n_l, label='trapz')
plt.legend()
plt.show()

# %%
plt.title('Press-Schechter Function')
plt.xlabel(r'Subhalo Mass [$M_{\odot}]$')
plt.xscale('log')
plt.yscale('log')
plt.ylabel(r'dN/dM $\,\,\,\, [\mathrm{Mpc}]^-3$')
# plt.plot(press_s.m_l[2:],press_s.den_n_l[2:], label='quad')
plt.plot(press_test.m_l,press_test.den_n_l, label='trapz')
plt.legend()
plt.show()

# %%
plt.title('Press-Schechter Function')
plt.xlabel(r'Subhalo Mass [$M_{\odot}]$')
plt.xscale('log')
#plt.yscale('log')
plt.ylabel('Number of lenses')
# plt.plot(press_s.m_l[2:],press_s.n_l[2:], label='quad')
plt.plot(press_test.m_l,press_test.n_l, label='trapz')
plt.legend()
plt.show()

# %% [markdown]
# ## Log-Likelihood testing

# %%
import pickle
import plotting as plot

with open('../results/samples_Roman_nfw_Press Schechter_1_1_2.pkl', 'rb') as f:
    data = pickle.load(f)

# %%
data.shape
# Out:
# (40, 2)

# %%
plt.plot(np.abs(data[:,0]))
#plt.yscale('log')
plt.title('Samples c200')
#plt.ylabel(r'$\mid \log \mathcal{L} \mid$');
plt.xlabel(r'N');

# %%
plt.plot(np.abs(data[:,1]))
#plt.yscale('log')
plt.title('Samples del_crit')
#plt.ylabel(r'$\mid \log \mathcal{L} \mid$');
plt.xlabel(r'N');

# %%
with open('../results/loglike_Roman_nfw_Press Schechter_1_1_2.pkl', 'rb') as f:
    data_log = pickle.load(f)

# %%
data_pruned.shape
# Out:
# (0,)

# %%
data_log.shape
# Out:
# (40,)

# %%
plt.plot(np.abs(data_log[:])) 
#plt.yscale('log')
plt.ylabel(r'$\mid \log \mathcal{L} \mid$');
plt.xlabel(r'N');
